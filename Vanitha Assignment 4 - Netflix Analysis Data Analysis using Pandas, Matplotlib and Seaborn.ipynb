# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Netflix_Analysis = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\Assignment 4 - Data Analysis using Pandas, Matplotlib and Seaborn\\netflix daily top 10.csv")
Netflix_Analysis.head(10)
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
# 5  2020-04-01     6                 6              -
# 6  2020-04-01     7                10              -
# 7  2020-04-01     8                 7              5
# 8  2020-04-01     9                 8              -
# 9  2020-04-01    10                 9              -
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
# 5   Car Masters: Rust to Riches  TV Show               Yes
# 6                    Unorthodox  TV Show               Yes
# 7                 Love is Blind  TV Show               Yes
# 8                       Badland    Movie               NaN
# 9                      Uncorked    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# 3         Mar 26, 2020               5                30
# 4         Mar 20, 2020               9                55
# 5         Sep 14, 2018               4                14
# 6         Mar 26, 2020               2                 5
# 7         Feb 13, 2020               9                40
# 8         Mar 26, 2020               4                11
# 9         Mar 27, 2020               4                15

# %%
Netflix_Analysis.shape
# Out:
# (7100, 10)

# %%
Netflix_Analysis.columns
# Out:
# Index(['As of', 'Rank', 'Year to Date Rank', 'Last Week Rank', 'Title', 'Type',
#        'Netflix Exclusive', 'Netflix Release Date', 'Days In Top 10',
#        'Viewership Score'],
#       dtype='object')

# %%
Netflix_Analysis.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
Netflix_Analysis.nunique()
# Out:
# As of                   710
# Rank                     10
# Year to Date Rank        11
# Last Week Rank           11
# Title                   645
# Type                      4
# Netflix Exclusive         1
# Netflix Release Date    414
# Days In Top 10          428
# Viewership Score        779
# dtype: int64

# %%
Netflix_Analysis.duplicated().sum()
# Out:
# 0

# %%
df = Netflix_Analysis.copy()

# %%
df.shape
# Out:
# (7100, 10)

# %%
df = df.dropna()
df.shape
# Out:
# (4599, 10)

# %%
df.head(10)
# Out:
#          As of  Rank Year to Date Rank Last Week Rank  \
# 0   2020-04-01     1                 1              1
# 1   2020-04-01     2                 2              -
# 4   2020-04-01     5                 5              4
# 5   2020-04-01     6                 6              -
# 6   2020-04-01     7                10              -
# 7   2020-04-01     8                 7              5
# 9   2020-04-01    10                 9              -
# 10  2020-04-02     1                 1              1
# 11  2020-04-02     2                 2              -
# 13  2020-04-02     4                 -              -
#
#                            Title     Type Netflix Exclusive  \
# 0   Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                          Ozark  TV Show               Yes
# 4                   The Platform    Movie               Yes
# 5    Car Masters: Rust to Riches  TV Show               Yes
# 6                     Unorthodox  TV Show               Yes
# 7                  Love is Blind  TV Show               Yes
# 9                       Uncorked    Movie               Yes
# 10  Tiger King: Murder, Mayhem …  TV Show               Yes
# 11                         Ozark  TV Show               Yes
# 13                    Nailed It!  TV Show               Yes
#
#    Netflix Release Date  Days In Top 10  Viewership Score
# 0          Mar 20, 2020               9                90
# 1          Jul 21, 2017               5                45
# 4          Mar 20, 2020               9                55
# 5          Sep 14, 2018               4                14
# 6          Mar 26, 2020               2                 5
# 7          Feb 13, 2020               9                40
# 9          Mar 27, 2020               4                15
# 10         Mar 20, 2020              10               100
# 11         Jul 21, 2017               6                54
# 13          Mar 9, 2018               1                 7

# %%
df.isnull().sum()
# Out:
# As of                   0
# Rank                    0
# Year to Date Rank       0
# Last Week Rank          0
# Title                   0
# Type                    0
# Netflix Exclusive       0
# Netflix Release Date    0
# Days In Top 10          0
# Viewership Score        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   datetime64[ns]
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   datetime64[ns]
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 554.8+ KB

# %%
df.drop_duplicates()
# Out:
#           As of  Rank Year to Date Rank Last Week Rank  \
# 0    2020-04-01     1                 1              1
# 1    2020-04-01     2                 2              -
# 2    2020-04-01     3                 3              2
# 3    2020-04-01     4                 4              -
# 4    2020-04-01     5                 5              4
# ...         ...   ...               ...            ...
# 7095 2022-03-11     6                 5              1
# 7096 2022-03-11     7                 7              2
# 7097 2022-03-11     8                 8              -
# 7098 2022-03-11     9                 9              7
# 7099 2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# 3                     Blood Father    Movie               NaN
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie               NaN
# 7098                       Shrek 2    Movie               NaN
# 7099                         Shrek    Movie               NaN
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0              2020-03-20               9                90
# 1              2017-07-21               5                45
# 2              2019-03-28               9                76
# 3              2020-03-26               5                30
# 4              2020-03-20               9                55
# ...                   ...             ...               ...
# 7095           2022-03-01              10                81
# 7096           2022-02-25              14               100
# 7097           2014-08-01               3                 7
# 7098           2022-03-01              10                33
# 7099           2018-05-01               7                12
#
# [7100 rows x 10 columns]

# %%
df.describe()
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %%
df['Year to Date Rank']=df['Year to Date Rank']
df['Last Week Rank']=df['Last Week Rank']
df['Netflix Release Date']=pd.to_datetime(df['Netflix Release Date'])
df['As of']=pd.to_datetime(df['As of'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   datetime64[ns]
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   datetime64[ns]
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 554.8+ KB

# %%
sns.countplot(Netflix_Analysis['Type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Type')

# %%
sns.countplot(Netflix_Analysis['Title'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Title')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Title')
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 137 (\x89) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('netflix daily top 10.csv')

# %%
df.head(5)
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# 3         Mar 26, 2020               5                30
# 4         Mar 20, 2020               9                55

# %%
df.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
df.fillna(0)
# Out:
#           As of  Rank Year to Date Rank Last Week Rank  \
# 0    2020-04-01     1                 1              1
# 1    2020-04-01     2                 2              -
# 2    2020-04-01     3                 3              2
# 3    2020-04-01     4                 4              -
# 4    2020-04-01     5                 5              4
# ...         ...   ...               ...            ...
# 7095 2022-03-11     6                 5              1
# 7096 2022-03-11     7                 7              2
# 7097 2022-03-11     8                 8              -
# 7098 2022-03-11     9                 9              7
# 7099 2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show                 0
# 3                     Blood Father    Movie                 0
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie                 0
# 7098                       Shrek 2    Movie                 0
# 7099                         Shrek    Movie                 0
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0              2020-03-20               9                90
# 1              2017-07-21               5                45
# 2              2019-03-28               9                76
# 3              2020-03-26               5                30
# 4              2020-03-20               9                55
# ...                   ...             ...               ...
# 7095           2022-03-01              10                81
# 7096           2022-02-25              14               100
# 7097           2014-08-01               3                 7
# 7098           2022-03-01              10                33
# 7099           2018-05-01               7                12
#
# [7100 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
df.describe()
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %%
df['Year to Date Rank'].describe()
# Out:
# count     7100
# unique      11
# top          -
# freq       859
# Name: Year to Date Rank, dtype: object

# %%
# Converting the data type for the following columns. 

df['Year to Date Rank']=df['Year to Date Rank']
df['Last Week Rank']=df['Last Week Rank']
df['Netflix Release Date']=pd.to_datetime(df['Netflix Release Date'])
df['As of']=pd.to_datetime(df['As of'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   datetime64[ns]
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   datetime64[ns]
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 554.8+ KB

# %%
sns.scatterplot(data=df, x=df['Days In Top 10'], y=df['Viewership Score'])
# Out:
# <AxesSubplot:xlabel='Days In Top 10', ylabel='Viewership Score'>

# %%
dd=np.corrcoef(df['Viewership Score'],df['Days In Top 10'])
dd[1, 0]
# Out:
# 0.9624135870948405

# %%
sns.set_style('whitegrid')
sns.countplot(data=df,x=df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
tv_shows=df[df['Type']=='TV Show']
tv_shows_top=tv_shows.groupby('Title')['Days In Top 10'].max().sort_values(ascending=False)[0:11]
tv_shows_top
# Out:
# Title
# Cocomelon               428
# Ozark                    89
# Cobra Kai                81
# Manifest                 80
# The Queenâs Gambit     73
# Outer Banks              72
# Squid Game               66
# All American             66
# Bridgerton               58
# Lucifer                  57
# Virgin River             55
# Name: Days In Top 10, dtype: int64

# %%
tv=tv_shows.groupby('Title').max()
tv=tv.sort_values(by='Days In Top 10',ascending=False)[:51]
tv_report = tv.groupby('Netflix Exclusive').count()

# %%
movies=df[df['Type']=='Movie']
movies_top=movies.groupby(df['Title'])['Days In Top 10'].max().sort_values(ascending=False)
movies_top[0:11]
# Out:
# Title
# The Mitchells vs. The Machines    31
# How the Grinch Stole Christmas    29
# Vivo                              29
# 365 Days                          28
# Despicable Me 2                   27
# Donât Look Up                   26
# The Christmas Chronicles 2        24
# Illumination Presents The G…      24
# We Can Be Heroes                  24
# Red Notice                        23
# The Unforgivable                  22
# Name: Days In Top 10, dtype: int64

# %%
stand_up=df[df['Type']=='Stand-Up Comedy']
stand_up_top=stand_up.groupby(df['Title'])['Days In Top 10'].max().sort_values(ascending=False)
stand_up_top=pd.DataFrame(stand_up_top)
stand_up_top
# Out:
#                                 Days In Top 10
# Title
# Dave Chappelle: The Closer                  16
# Kevin Hart: Zero F**ks Given                10
# George Lopez: Weâll Do It f…               5
# Jerry Seinfeld: 23 Hours to…                 5
# Chris DâElia: No Pain                      3
# Bo Burnham: Inside                           2

# %%
zz=stand_up.groupby(df['Title']).max()
zz=zz.sort_values(by='Days In Top 10',ascending=False)
stand_up_report = zz.groupby(['Netflix Exclusive']).count()
stand_up_report['percentage'] = (stand_up_report['Days In Top 10']/stand_up_report['Days In Top 10'].sum())*100
stand_up_report[['Days In Top 10','percentage']]
# Out:
#                    Days In Top 10  percentage
# Netflix Exclusive
# Yes                             6       100.0

# %%
zz=stand_up.groupby(df['Title']).max()
zz=zz.sort_values(by='Days In Top 10',ascending=False)
stand_up_report = zz.groupby(['Netflix Exclusive']).count()
stand_up_report['percentage'] = (stand_up_report['Days In Top 10']/stand_up_report['Days In Top 10'].sum())*100
stand_up_report[['Days In Top 10','percentage']]
# Out:
#                    Days In Top 10  percentage
# Netflix Exclusive
# Yes                             6       100.0

# %%
tv_shows=df[df['Type']=='TV Show']
tv_shows_top=tv_shows.groupby('Title')['Days In Top 10'].max().sort_values(ascending=False)[0:51]
tv_shows_top
# Out:
# Title
# Cocomelon                         428
# Ozark                              89
# Cobra Kai                          81
# Manifest                           80
# The Queenâs Gambit               73
# Outer Banks                        72
# Squid Game                         66
# All American                       66
# Bridgerton                         58
# Lucifer                            57
# Virgin River                       55
# Maid                               49
# Too Hot to Handle                  48
# Emily in Paris                     48
# Love is Blind                      46
# The Witcher                        45
# Sweet Magnolias                    45
# Ginny & Georgia                    44
# The Queen of Flow                  44
# Tiger King                         44
# Shameless                          42
# Who Killed Sara?                   42
# iCarly                             42
# The Circle US                      40
# Money Heist                        39
# Avatar: The Last Airbender         39
# Tiger King: Murder, Mayhem …       37
# You                                35
# Clickbait                          34
# Riverdale                          34
# The Umbrella Academy               34
# Unsolved Mysteries                 33
# Space Force                        32
# Jurassic World Camp Cretaceous     31
# Jeffrey Epstein: Filthy Rich       30
# All of Us Are Dead                 29
# Inventing Anna                     28
# Never Have I Ever                  28
# Firefly Lane                       27
# Sweet Tooth                        26
# Sex/Life                           26
# The Haunting of Bly Manor          26
# Jurassic World: Camp Cretac…       26
# The Crown                          26
# Big Mouth                          26
# Good Girls                         26
# Ratched                            26
# Behind Her Eyes                    26
# The Serpent                        25
# Dead to Me                         25
# The Great British Baking Show      24
# Name: Days In Top 10, dtype: int64

# %%
Netflix_Analysis['Type']
# Out:
# 0       TV Show
# 1       TV Show
# 2       TV Show
# 3         Movie
# 4         Movie
#          ...
# 7095    TV Show
# 7096    TV Show
# 7097      Movie
# 7098      Movie
# 7099      Movie
# Name: Type, Length: 7100, dtype: object

# %%
movies=df[df['Type']=='Movie']
movies
# Out:
#            As of  Rank Year to Date Rank Last Week Rank         Title   Type  \
# 3     2020-04-01     4                 4              -  Blood Father  Movie
# 4     2020-04-01     5                 5              4  The Platform  Movie
# 8     2020-04-01     9                 8              -       Badland  Movie
# 9     2020-04-01    10                 9              -      Uncorked  Movie
# 15    2020-04-02     6                 4              -  Blood Father  Movie
# ...          ...   ...               ...            ...           ...    ...
# 7088  2022-03-10     9                 7              7       Shrek 2  Movie
# 7089  2022-03-10    10                 8              -         Shrek  Movie
# 7097  2022-03-11     8                 8              -       Shooter  Movie
# 7098  2022-03-11     9                 9              7       Shrek 2  Movie
# 7099  2022-03-11    10                10              -         Shrek  Movie
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 3                  NaN         Mar 26, 2020               5                30
# 4                  Yes         Mar 20, 2020               9                55
# 8                  NaN         Mar 26, 2020               4                11
# 9                  Yes         Mar 27, 2020               4                15
# 15                 NaN         Mar 26, 2020               6                35
# ...                ...                  ...             ...               ...
# 7088               NaN          Mar 1, 2022               9                31
# 7089               NaN          May 1, 2018               6                11
# 7097               NaN          Aug 1, 2014               3                 7
# 7098               NaN          Mar 1, 2022              10                33
# 7099               NaN          May 1, 2018               7                12
#
# [2611 rows x 10 columns]

# %%
movies=df[df['Type']=='Stand-Up Comedy']
movies
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 143   2020-04-15     4                 -              -
# 153   2020-04-16     4                 4              -
# 168   2020-04-17     9                 4              -
# 355   2020-05-06     6                 -              -
# 362   2020-05-07     3                 6              -
# 374   2020-05-08     5                 3              -
# 387   2020-05-09     8                 5              -
# 397   2020-05-10     8                 8              -
# 912   2020-07-01     3                 -              -
# 923   2020-07-02     4                 3              -
# 936   2020-07-03     7                 4              -
# 947   2020-07-04     8                 7              -
# 958   2020-07-05     9                 8              -
# 2311  2020-11-18     2                 -              -
# 2321  2020-11-19     2                 2              -
# 2332  2020-11-20     3                 2              -
# 2342  2020-11-21     3                 3              -
# 2351  2020-11-22     2                 3              -
# 2361  2020-11-23     2                 2              -
# 2372  2020-11-24     3                 2              -
# 2384  2020-11-25     5                 3              2
# 2396  2020-11-26     7                 5              2
# 2407  2020-11-27     8                 7              3
# 4339  2021-06-08    10                 -              -
# 4359  2021-06-10    10                 -              -
# 5543  2021-10-07     4                 -              -
# 5553  2021-10-08     4                 4              -
# 5562  2021-10-09     3                 4              -
# 5572  2021-10-10     3                 3              -
# 5582  2021-10-11     3                 3              -
# 5592  2021-10-12     3                 3              -
# 5602  2021-10-13     3                 3              -
# 5613  2021-10-14     4                 3              4
# 5623  2021-10-15     4                 4              4
# 5634  2021-10-16     5                 4              3
# 5645  2021-10-17     6                 5              3
# 5657  2021-10-18     8                 6              3
# 5668  2021-10-19     9                 8              3
# 5689  2021-10-21    10                 -              4
# 5698  2021-10-22     9                10              4
# 5709  2021-10-23    10                 9              5
#
#                                Title             Type Netflix Exclusive  \
# 143          Chris DâElia: No Pain  Stand-Up Comedy               Yes
# 153          Chris DâElia: No Pain  Stand-Up Comedy               Yes
# 168          Chris DâElia: No Pain  Stand-Up Comedy               Yes
# 355     Jerry Seinfeld: 23 Hours to…  Stand-Up Comedy               Yes
# 362     Jerry Seinfeld: 23 Hours to…  Stand-Up Comedy               Yes
# 374     Jerry Seinfeld: 23 Hours to…  Stand-Up Comedy               Yes
# 387     Jerry Seinfeld: 23 Hours to…  Stand-Up Comedy               Yes
# 397     Jerry Seinfeld: 23 Hours to…  Stand-Up Comedy               Yes
# 912   George Lopez: Weâll Do It f…  Stand-Up Comedy               Yes
# 923   George Lopez: Weâll Do It f…  Stand-Up Comedy               Yes
# 936   George Lopez: Weâll Do It f…  Stand-Up Comedy               Yes
# 947   George Lopez: Weâll Do It f…  Stand-Up Comedy               Yes
# 958   George Lopez: Weâll Do It f…  Stand-Up Comedy               Yes
# 2311    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2321    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2332    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2342    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2351    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2361    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2372    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2384    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2396    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 2407    Kevin Hart: Zero F**ks Given  Stand-Up Comedy               Yes
# 4339              Bo Burnham: Inside  Stand-Up Comedy               Yes
# 4359              Bo Burnham: Inside  Stand-Up Comedy               Yes
# 5543      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5553      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5562      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5572      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5582      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5592      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5602      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5613      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5623      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5634      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5645      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5657      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5668      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5689      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5698      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
# 5709      Dave Chappelle: The Closer  Stand-Up Comedy               Yes
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 143          Apr 14, 2020               1                 7
# 153          Apr 14, 2020               2                14
# 168          Apr 14, 2020               3                16
# 355           May 5, 2020               1                 5
# 362           May 5, 2020               2                13
# 374           May 5, 2020               3                19
# 387           May 5, 2020               4                22
# 397           May 5, 2020               5                25
# 912          Jun 30, 2020               1                 8
# 923          Jun 30, 2020               2                15
# 936          Jun 30, 2020               3                19
# 947          Jun 30, 2020               4                22
# 958          Jun 30, 2020               5                24
# 2311         Nov 17, 2020               1                 9
# 2321         Nov 17, 2020               2                18
# 2332         Nov 17, 2020               3                26
# 2342         Nov 17, 2020               4                34
# 2351         Nov 17, 2020               5                43
# 2361         Nov 17, 2020               6                52
# 2372         Nov 17, 2020               7                60
# 2384         Nov 17, 2020               8                66
# 2396         Nov 17, 2020               9                70
# 2407         Nov 17, 2020              10                73
# 4339         May 30, 2021               1                 1
# 4359         May 30, 2021               2                 2
# 5543          Oct 5, 2021               1                 7
# 5553          Oct 5, 2021               2                14
# 5562          Oct 5, 2021               3                22
# 5572          Oct 5, 2021               4                30
# 5582          Oct 5, 2021               5                38
# 5592          Oct 5, 2021               6                46
# 5602          Oct 5, 2021               7                54
# 5613          Oct 5, 2021               8                61
# 5623          Oct 5, 2021               9                68
# 5634          Oct 5, 2021              10                74
# 5645          Oct 5, 2021              11                79
# 5657          Oct 5, 2021              12                82
# 5668          Oct 5, 2021              13                84
# 5689          Oct 5, 2021              14                85
# 5698          Oct 5, 2021              15                87
# 5709          Oct 5, 2021              16                88
