# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"iphone12pro"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
flipkart_url2 = "https://www.flipkart.com/search?q="+"TV"

# %%
flipkart_url2
# Out:
# 'https://www.flipkart.com/search?q=TV'

# %%
URLclient = urlopen(flipkart_url2)

# %%
# URLclient.read() # dont run because its assigned

# %%
flipkart_page = URLclient.read()

# %%
flipkart_page # this is not stuctured format, we have do this in to human readable formate
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html = bs(flipkart_page , 'html.parser') # this simplify little bit but my object is to read tv one by one

# %%
"https://www.flipkart.com" + "/samsung-crystal-4k-108-cm-43-inch-ultra-hd-4k-led-smart-tizen-tv/p/itm7dcfb3cc69fbb?pid=TVSG2CG7F2Y9YUJ3&lid=LSTTVSG2CG7F2Y9YUJ38041NS&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_Zj39DvxdPmcfdBjE%2BeTL4B0pNBrrmT2GDRP7bfosAXt9Ln6fpaqGaAnvzeQ8SRjSfeD667RBpIhJFCANn%2BKE1w%3D%3D&ppt=None&ppn=None&ssid=3362t56qvk0000001683754889328&qH=271ddf829afeece4"
# Out:
# 'https://www.flipkart.com/samsung-crystal-4k-108-cm-43-inch-ultra-hd-4k-led-smart-tizen-tv/p/itm7dcfb3cc69fbb?pid=TVSG2CG7F2Y9YUJ3&lid=LSTTVSG2CG7F2Y9YUJ38041NS&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_Zj39DvxdPmcfdBjE%2BeTL4B0pNBrrmT2GDRP7bfosAXt9Ln6fpaqGaAnvzeQ8SRjSfeD667RBpIhJFCANn%2BKE1w%3D%3D&ppt=None&ppn=None&ssid=3362t56qvk0000001683754889328&qH=271ddf829afeece4'

# %% [raw]
# class="_1fQZEK" target="_blank" rel="noopener noreferrer" href="/samsung-crystal-4k-108-cm-43-inch-ultra-hd-4k-led-smart-tizen-tv/p/itm7dcfb3cc69fbb?pid=TVSG2CG7F2Y9YUJ3&amp;lid=LSTTVSG2CG7F2Y9YUJ38041NS&amp;marketplace=FLIPKART&amp;q=TV&amp;store=ckf%2Fczl&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=en_Zj39DvxdPmcfdBjE%2BeTL4B0pNBrrmT2GDRP7bfosAXt9Ln6fpaqGaAnvzeQ8SRjSfeD667RBpIhJFCANn%2BKE1w%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=3362t56qvk0000001683754889328&amp;qH=271ddf829afeece4"><div class="MIXNux" data-tkid="ADVIEW_en_Zj39DvxdPmcfdBjE+eTL4B0pNBrrmT2GDRP7bfosAXt9Ln6fpaqGaAnvzeQ8SRjSfeD667RBpIhJFCANn+KE1w=="><div class="_2QcLo-"><div><div class="CXW8mj" style="height: 200px; width: 200px;"><img loading="eager" class="_396cs4" alt="SAMSUNG Crystal 4K 108 cm (43

# %%
bigbox = flipkart_html.find_all("div" , {"class" :"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
len(bigbox)
# Out:
# 27

# %%
bigbox[0].div.div.div.a['href']
# Out:
# '/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_dFe7sLpNc9tgTsFgk%2F8%2BNI%2B5ZonX8YLzEcOI3OVFrk5cVS8sD5wI6i%2FDt%2FYv7F7gA2sb1SLQgA0ri0G0kGDZhg%3D%3D&ppt=None&ppn=None&ssid=0x3vsr1fkw0000001683754255259&qH=271ddf829afeece4'

# %%
"https://www.flipkart.com" +bigbox[0].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_dFe7sLpNc9tgTsFgk%2F8%2BNI%2B5ZonX8YLzEcOI3OVFrk5cVS8sD5wI6i%2FDt%2FYv7F7gA2sb1SLQgA0ri0G0kGDZhg%3D%3D&ppt=None&ppn=None&ssid=0x3vsr1fkw0000001683754255259&qH=271ddf829afeece4'

# %%
for i in bigbox:
        print ("https://www.flipkart.com" +i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_dFe7sLpNc9tgTsFgk%2F8%2BNI%2B5ZonX8YLzEcOI3OVFrk5cVS8sD5wI6i%2FDt%2FYv7F7gA2sb1SLQgA0ri0G0kGDZhg%3D%3D&ppt=None&ppn=None&ssid=0x3vsr1fkw0000001683754255259&qH=271ddf829afeece4
# https://www.flipkart.com/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-bezel-free-design/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNCPAW6M&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&spotlightTagId=BestsellerId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=1321c861-f03f-4148-b943-ac38022a6bc0.TVSGHY2UZA9YHWQN.SEARCH&ppt=None&ppn=None&ssid=0x3vsr1fkw0000001683754255259&qH=271ddf829afeece4
# ...

# %%
productlink = "https://www.flipkart.com" +bigbox[0].div.div.div.a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=TV&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_dFe7sLpNc9tgTsFgk%2F8%2BNI%2B5ZonX8YLzEcOI3OVFrk5cVS8sD5wI6i%2FDt%2FYv7F7gA2sb1SLQgA0ri0G0kGDZhg%3D%3D&ppt=None&ppn=None&ssid=0x3vsr1fkw0000001683754255259&qH=271ddf829afeece4'

# %%
requests.get(productlink)
# Out:
# <Response [200]>

# %%
product_req = requests.get(productlink)

# %%
product_req
# Out:
# <Response [200]>

# %%
product_req.text # again it will come back as a cant readable form
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
bs(product_req.text,'html.parser')
# Out:
# <!DOCTYPE html>
# ...

# %%
product_html = bs(product_req.text,'html.parser')

# %%
product_html.find_all("div",{"class":"_16PBlm"})
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Terrific purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. <br>PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.<br> <br> BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.<br/><br/>SOUND: tv speakers doesn't have much bass, ide...</br></br></br></div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">nishant yadav</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" w
# ...

# %%
comment_box = product_html.find_all("div",{"class":"_16PBlm"})

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">nishant yadav</p>]

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">nishant yadav</p>

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'nishant yadav'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# nishant yadav
# sai kumar
# shabab khan
# Deepak Rai
# Flipkart Customer
# Flipkart Customer
# SANTHOSH PILLALAMARRI
# RAJESH HEGDE
# MANISH THAKURDESAI
# Shobhit Saxena
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9252\3047202390.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div
# Out:
# <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9252\2339363835.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#       3
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Terrific purchase'

# %%
comment_box[1].div.div.div.p.text
# Out:
# 'Awesome'

# %%
comment_box[5].div.div.div.p.text
# Out:
# 'Nice product'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Terrific purchase
# Awesome
# Mind-blowing purchase
# Very Good
# Delightful
# Nice product
# Terrific
# Highly recommended
# Highly recommended
# Excellent
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9252\4044681715.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all("div",{"class":""})
# Out:
# [<div><div class="">This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. <br>PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.<br> <br> BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.<br/><br/>SOUND: tv speakers doesn't have much bass, ide...</br></br></br></div><span class="_1BWGvX"><span>READ MORE</span></span></div>,
# ...

# %%
comment_box[0].div.div.find_all("div",{"class":""})[0].text
# Out:
# "This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.  BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.SOUND: tv speakers doesn't have much bass, ide...READ MORE"

# %%
for i in comment_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.  BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.SOUND: tv speakers doesn't have much bass, ide...READ MORE
# Super and good quality full HD ,Internet also speed connecting ,it is like one smart phone .full happy and it delivered so speedREAD MORE
# First i have to thanks to Flipkart delivered soon  and mi 5A 32inc  tv is superb fantastic mind blowing picture hawsome and connectivity is so fast  very good service and thankq a lot .READ MORE
# ...
